# %%
import os

dataset_path = "lemon_leaf"

total = 0

for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)

    if os.path.isdir(class_path):
        count = len([
            f for f in os.listdir(class_path)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ])

        print(class_name, ":", count)
        total += count

print("\n🔥 Total Images in Dataset:", total)
# Out:
# Anthracnose : 960
# Curl Virus : 908
# Dry Leaf : 988
# Healthy Leaf : 965
# Spider Mites : 997
# Citrus Canker : 919
# Deficiency Leaf : 925
# Sooty Mould : 997
# Bacterial Blight : 985
#
# 🔥 Total Images in Dataset: 8644

# %%
import os
from PIL import Image

dataset_path = "lemon_leaf"

total = 0

for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)

    if os.path.isdir(class_path):
        count = 0
        sizes = {}

        for file in os.listdir(class_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):

                img_path = os.path.join(class_path, file)

                try:
                    img = Image.open(img_path)
                    size = img.size  # (width, height)

                    sizes[size] = sizes.get(size, 0) + 1
                    count += 1

                except:
                    pass

        print(f"\nClass: {class_name}")
        print(f"Total Images: {count}")

        for k, v in sizes.items():
            print(f"Pixel Size {k}: {v} images")

        total += count

print("\n🔥 Total Images in Dataset:", total)
# Out:
# Class: Anthracnose
# Total Images: 960
# Pixel Size (224, 224): 960 images
#
# Class: Curl Virus
# Total Images: 908
# Pixel Size (224, 224): 908 images
#
# Class: Dry Leaf
# Total Images: 988
# Pixel Size (224, 224): 988 images
#
# Class: Healthy Leaf
# Total Images: 965
# Pixel Size (224, 224): 965 images
#
# Class: Spider Mites
# Total Images: 997
# Pixel Size (224, 224): 997 images
#
# Class: Citrus Canker
# Total Images: 919
# Pixel Size (224, 224): 919 images
#
# Class: Deficiency Leaf
# Total Images: 925
# Pixel Size (224, 224): 925 images
#
# Class: Sooty Mould
# Total Images: 997
# Pixel Size (224, 224): 997 images
#
# Class: Bacterial Blight
# Total Images: 985
# Pixel Size (224, 224): 985 images
#
# 🔥 Total Images in Dataset: 8644

# %%
import os

dataset_path = "lemon_leaf_dataset/test"

total = 0

for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)

    if os.path.isdir(class_path):
        count = len([
            f for f in os.listdir(class_path)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ])

        print(class_name, ":", count)
        total += count

print("\n🔥 Total Images in Dataset:", total)
# Out:
# Anthracnose : 192
# Curl Virus : 182
# Dry Leaf : 198
# Healthy Leaf : 193
# Spider Mites : 200
# Citrus Canker : 184
# Deficiency Leaf : 185
# Sooty Mould : 200
# Bacterial Blight : 197
#
# 🔥 Total Images in Dataset: 1731

# %%
import os

dataset_path = "lemon_leaf_dataset/train"

total = 0

for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)

    if os.path.isdir(class_path):
        count = len([
            f for f in os.listdir(class_path)
            if f.lower().endswith(('.jpg', '.jpeg', '.png'))
        ])

        print(class_name, ":", count)
        total += count

print("\n🔥 Total Images in Dataset:", total)
# Out:
# Anthracnose : 768
# Curl Virus : 726
# Dry Leaf : 790
# Healthy Leaf : 772
# Spider Mites : 797
# Citrus Canker : 735
# Deficiency Leaf : 740
# Sooty Mould : 797
# Bacterial Blight : 788
#
# 🔥 Total Images in Dataset: 6913
