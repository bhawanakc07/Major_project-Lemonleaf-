# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install pillow
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
#Resize Dataset to 224×224
import os
from PIL import Image

dataset_path = "RP_lemonleaf"
output_path = "RP_lemonleaf_resized"

# create output folder
os.makedirs(output_path, exist_ok=True)

for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):
        save_folder = os.path.join(output_path, folder)
        os.makedirs(save_folder, exist_ok=True)

        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):

                img_path = os.path.join(folder_path, file)

                try:
                    img = Image.open(img_path)
                    img = img.convert("RGB")   # ensure 3 channels
                    img = img.resize((224, 224))  # resize here

                    img.save(os.path.join(save_folder, file))

                except:
                    pass

print("✅ All images resized to 224x224 successfully!")
# Out:
# ✅ All images resized to 224x224 successfully!

# %%
import os
from PIL import Image

dataset_path = "IEEE_lemonleaf/Original_Dataset"
output_path = "IEEE_lemonleaf_resized"

# create output folder
os.makedirs(output_path, exist_ok=True)

for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):
        save_folder = os.path.join(output_path, folder)
        os.makedirs(save_folder, exist_ok=True)

        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):

                img_path = os.path.join(folder_path, file)

                try:
                    img = Image.open(img_path)
                    img = img.convert("RGB")   # ensure 3 channels
                    img = img.resize((224, 224))  # resize here

                    img.save(os.path.join(save_folder, file))

                except:
                    pass

print("✅ All images resized to 224x224 successfully!")
# Out:
# ✅ All images resized to 224x224 successfully!

# %%
#Check pixel sizes
import os
import pandas as pd
from PIL import Image

dataset_path = "RP_lemonleaf_resized"

data = []

for folder in sorted(os.listdir(dataset_path)):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):
        image_count = 0
        sample_size = None

        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_count += 1

                if sample_size is None:
                    img = Image.open(os.path.join(folder_path, file))
                    sample_size = img.size

        data.append([folder, image_count, sample_size])

df = pd.DataFrame(data, columns=["Class", "Number of Images", "Pixel Size"])
df
# Out:
#                                        Class  Number of Images  Pixel Size
# 0                                Anthracnose               609  (224, 224)
# 1                              Citrus_Canker               623  (224, 224)
# 2              Citrus_Greening_Huanglongbing               618  (224, 224)
# 3                           Citrus_Leaf_Curl               634  (224, 224)
# 4                           Citrus_Leafminer               650  (224, 224)
# 5                         Healthy Lemon Leaf               630  (224, 224)
# 6  Swallowtail Larval Herbivory (Deficiency)               630  (224, 224)

# %%
import os
import pandas as pd
from PIL import Image

dataset_path = "IEEE_lemonleaf_resized"

data = []

for folder in sorted(os.listdir(dataset_path)):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):
        image_count = 0
        sample_size = None

        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_count += 1

                if sample_size is None:
                    img = Image.open(os.path.join(folder_path, file))
                    sample_size = img.size

        data.append([folder, image_count, sample_size])

df = pd.DataFrame(data, columns=["Class", "Number of Images", "Pixel Size"])
df
# Out:
#               Class  Number of Images  Pixel Size
# 0       Anthracnose               100  (224, 224)
# 1  Bacterial Blight               100  (224, 224)
# 2     Citrus Canker               100  (224, 224)
# 3        Curl Virus               100  (224, 224)
# 4   Deficiency Leaf               100  (224, 224)
# 5          Dry Leaf               100  (224, 224)
# 6      Healthy Leaf               100  (224, 224)
# 7       Sooty Mould               100  (224, 224)
# 8      Spider Mites               100  (224, 224)

# %%
#Merge two folder
import os
import shutil

dataset_paths = [
    "IEEE_lemonleaf_resized",
    "RP_lemonleaf_resized"
]

output_path = "lemonleaf"

os.makedirs(output_path, exist_ok=True)

for dataset in dataset_paths:
    for folder in os.listdir(dataset):
        src_folder = os.path.join(dataset, folder)

        if os.path.isdir(src_folder):
            dest_folder = os.path.join(output_path, folder)
            os.makedirs(dest_folder, exist_ok=True)

            for file in os.listdir(src_folder):
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):

                    src_file = os.path.join(src_folder, file)

                    # avoid overwrite (important when merging datasets)
                    new_name = f"{dataset.split('/')[-1]}_{file}"
                    dest_file = os.path.join(dest_folder, new_name)

                    shutil.copy(src_file, dest_file)

print("✅ Both datasets merged into 'lemonleaf' successfully!")
# Out:
# ✅ Both datasets merged into 'lemonleaf' successfully!

# %%
import os
import pandas as pd
from PIL import Image

dataset_path = "lemonleaf"

data = []

for folder in sorted(os.listdir(dataset_path)):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):
        image_count = 0
        sample_size = None

        for file in os.listdir(folder_path):
            if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_count += 1

                if sample_size is None:
                    img = Image.open(os.path.join(folder_path, file))
                    sample_size = img.size

        data.append([folder, image_count, sample_size])

df = pd.DataFrame(data, columns=["Class", "Number of Images", "Pixel Size"])
df
# Out:
#               Class  Number of Images  Pixel Size
# 0       Anthracnose               709  (224, 224)
# 1  Bacterial Blight               100  (224, 224)
# 2     Citrus Canker               723  (224, 224)
# 3        Curl Virus               734  (224, 224)
# 4   Deficiency Leaf               730  (224, 224)
# 5          Dry Leaf               100  (224, 224)
# 6      Healthy Leaf               730  (224, 224)
# 7       Sooty Mould               100  (224, 224)
# 8      Spider Mites               100  (224, 224)
